# %%
import pandas as pd
import collections
import nltk

# %% [markdown]
# Copy the keywords you've got ready to go

# %%
df = pd.read_clipboard(sep="\n", names=["kws"])

# %%
from nltk.corpus import stopwords

# %% [markdown]
# First you run this, you'll need to do this step.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dom_W\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords = set(stopwords.words('english'))

# %%
list_of_keywords = list(filter(None,df['kws'].tolist()))

list_of_words_in_keywords = [x.split(" ") for x in list_of_keywords]

counts = collections.Counter()   # or nltk.FreqDist()
for phrase in list_of_words_in_keywords:
    phrase_no_stop = [w for w in phrase if not w in stopwords]
    counts.update(nltk.ngrams(phrase_no_stop, 1))
    counts.update(nltk.ngrams(phrase_no_stop, 2))
    counts.update(nltk.ngrams(phrase_no_stop, 3))

counts.most_common(200)
# Out:
# [(('management',), 64),
#  (('employee',), 58),
#  (('engagement',), 47),
#  (('employee', 'engagement'), 35),
#  (('leadership',), 24),
#  (('training',), 23),
#  (('performance',), 22),
#  (('performance', 'management'), 22),
#  (('software',), 16),
#  (('survey',), 15),
#  (('time',), 14),
#  (('management', 'training'), 13),
#  (('staff',), 11),
#  (('development',), 10),
#  (('management', 'software'), 9),
#  (('leadership', 'training'), 8),
#  (('tracking',), 8),
#  (('time', 'tracking'), 8),
#  (('leadership', 'development'), 7),
#  (('courses',), 7),
#  (('examples',), 6),
#  (('engagement', 'survey'), 6),
#  (('human',), 6),
#  (('system',), 6),
#  (('management', 'system'), 6),
#  (('time', 'management'), 6),
#  (('questions',), 5),
#  (('training', 'courses'), 5),
#  (('resource',), 5),
#  (('human', 'resource'), 5),
#  (('resource', 'management'), 5),
#  (('human', 'resource', 'management'), 5),
#  (('free',), 5),
#  (('appraisal',), 4),
#  (('employee', 'appraisal'), 4),
#  (('employee', 'engagement', 'survey'), 4),
#  (('survey', 'questions'), 4),
#  (('app',), 4),
#  (('satisfaction',), 4),
#  (('satisfaction', 'survey'), 4),
#  (('tracking', 'software'), 4),
#  (('time', 'tracking', 'software'), 4),
#  (('ideas',), 3),
#  (('engagement', 'ideas'), 3),
#  (('gallup',), 3),
#  (('programs',), 3),
#  (('improving',), 3),
#  (('staff', 'engagement'), 3),
#  (('team',), 3),
#  (('workplace',), 3),
#  (('exit',), 3),
#  (('feedback',), 3),
#  (('employee', 'feedback'), 3),
#  (('management', 'training', 'courses'), 3),
#  (('plan',), 3),
#  (('employee', 'management'), 3),
#  (('hr',), 3),
#  (('onboarding',), 3),
#  (('systems',), 3),
#  (('timesheet',), 3),
#  (('employee', 'time'), 3),
#  (('employee', 'time', 'tracking'), 3),
#  (('form',), 2),
#  (('theory',), 2),
#  (('cipd',), 2),
#  (('gallup', 'employee'), 2),
#  (('gallup', 'employee', 'engagement'), 2),
#  (('strategies',), 2),
#  (('activities',), 2),
#  (('model',), 2),
#  (('surveys',), 2),
#  (('companies',), 2),
#  (('best',), 2),
#  (('practices',), 2),
#  (('best', 'practices'), 2),
#  (('case',), 2),
#  (('study',), 2),
#  (('case', 'study'), 2),
#  (('questionnaire',), 2),
#  (('importance',), 2),
#  (('retention',), 2),
#  (('employee', 'survey'), 2),
#  (('employee', 'satisfaction'), 2),
#  (('employee', 'satisfaction', 'survey'), 2),
#  (('team', 'engagement'), 2),
#  (('job',), 2),
#  (('people',), 2),
#  (('interviews',), 2),
#  (('exit', 'interviews'), 2),
#  (('harassment',), 2),
#  (('good',), 2),
#  (('skills',), 2),
#  (('leadership', 'skills'), 2),
#  (('360',), 2),
#  (('leadership', 'training', 'courses'), 2),
#  (('leadership', 'management'), 2),
#  (('leadership', 'management', 'training'), 2),
#  (('training', 'programs'), 2),
#  (('managers',), 2),
#  (('program',), 2),
#  (('development', 'plan'), 2),
#  (('online',), 2),
#  (('project',), 2),
#  (('project', 'management'), 2),
#  (('project', 'management', 'training'), 2),
#  (('change',), 2),
#  (('change', 'management'), 2),
#  (('hr', 'management'), 2),
#  (('absence',), 2),
#  (('absence', 'management'), 2),
#  (('process',), 2),
#  (('performance', 'management', 'system'), 2),
#  (('performance', 'management', 'software'), 2),
#  (('business',), 2),
#  (('components',), 2),
#  (('management', 'systems'), 2),
#  (('timesheet', 'app'), 2),
#  (('software', 'free'), 2),
#  (('comments',), 1),
#  (('appraisal', 'comments'), 1),
#  (('employee', 'appraisal', 'comments'), 1),
#  (('appraisal', 'form'), 1),
#  (('employee', 'appraisal', 'form'), 1),
#  (('appraisal', 'examples'), 1),
#  (('employee', 'appraisal', 'examples'), 1),
#  (('diversity',), 1),
#  (('employee', 'diversity'), 1),
#  (('employee', 'engagement', 'ideas'), 1),
#  (('engagement', 'theory'), 1),
#  (('employee', 'engagement', 'theory'), 1),
#  (('engagement', 'cipd'), 1),
#  (('employee', 'engagement', 'cipd'), 1),
#  (('consultant',), 1),
#  (('engagement', 'consultant'), 1),
#  (('employee', 'engagement', 'consultant'), 1),
#  (('engagement', 'strategies'), 1),
#  (('employee', 'engagement', 'strategies'), 1),
#  (('engagement', 'activities'), 1),
#  (('employee', 'engagement', 'activities'), 1),
#  (('benefits',), 1),
#  (('benefits', 'employee'), 1),
#  (('benefits', 'employee', 'engagement'), 1),
#  (('engagement', 'model'), 1),
#  (('employee', 'engagement', 'model'), 1),
#  (('strategy',), 1),
#  (('engagement', 'strategy'), 1),
#  (('employee', 'engagement', 'strategy'), 1),
#  (('engagement', 'software'), 1),
#  (('employee', 'engagement', 'software'), 1),
#  (('measuring',), 1),
#  (('measuring', 'employee'), 1),
#  (('measuring', 'employee', 'engagement'), 1),
#  (('engagement', 'survey', 'questions'), 1),
#  (('engagement', 'app'), 1),
#  (('employee', 'engagement', 'app'), 1),
#  (('engagement', 'programs'), 1),
#  (('employee', 'engagement', 'programs'), 1),
#  (('engagement', 'surveys'), 1),
#  (('employee', 'engagement', 'surveys'), 1),
#  (('engagement', 'examples'), 1),
#  (('employee', 'engagement', 'examples'), 1),
#  (('providers',), 1),
#  (('survey', 'providers'), 1),
#  (('engagement', 'survey', 'providers'), 1),
#  (('improve',), 1),
#  (('improve', 'employee'), 1),
#  (('improve', 'employee', 'engagement'), 1),
#  (('engagement', 'companies'), 1),
#  (('employee', 'engagement', 'companies'), 1),
#  (('dissertation',), 1),
#  (('engagement', 'dissertation'), 1),
#  (('employee', 'engagement', 'dissertation'), 1),
#  (('engagement', 'best'), 1),
#  (('employee', 'engagement', 'best'), 1),
#  (('engagement', 'best', 'practices'), 1),
#  (('google',), 1),
#  (('google', 'employee'), 1),
#  (('google', 'employee', 'engagement'), 1),
#  (('platform',), 1),
#  (('engagement', 'platform'), 1),
#  (('employee', 'engagement', 'platform'), 1),
#  (('engagement', 'questions'), 1),
#  (('employee', 'engagement', 'questions'), 1),
#  (('engagement', 'case'), 1),
#  (('employee', 'engagement', 'case'), 1),
#  (('engagement', 'case', 'study'), 1),
#  (('initiatives',), 1),
#  (('engagement', 'initiatives'), 1),
#  (('employee', 'engagement', 'initiatives'), 1),
#  (('barriers',), 1),
#  (('barriers', 'employee'), 1),
#  (('barriers', 'employee', 'engagement'), 1),
#  (('research',), 1),
#  (('engagement', 'research'), 1),
#  (('employee', 'engagement', 'research'), 1),
#  (('improving', 'employee'), 1),
#  (('improving', 'employee', 'engagement'), 1),
#  (('engagement', 'questionnaire'), 1),
#  (('employee', 'engagement', 'questionnaire'), 1),
#  (('importance', 'employee'), 1)]
